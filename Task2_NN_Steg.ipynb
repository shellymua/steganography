# %% [markdown]
# Set up torchvision:
# conda install torchvision -c soumith

# %%
# Imports necessary libraries and modules
from itertools import islice
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import torch
from torch.autograd import Variable
from torch import utils
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import os 
import pickle
from torchvision import datasets, utils
import torchvision.transforms as transforms
from torchvision.transforms import ToPILImage
from random import shuffle
from IPython.display import Image

# avoid error
# OMP: Error #15: Initializing libiomp5md.dll, but found libiomp5md.dll already initialized.
os.environ['KMP_DUPLICATE_LIB_OK'] = 'TRUE'

# %%
# Directory path
os.chdir("C:\\Users\\lidao\\Desktop\\project3\\")
cwd = 'input'

# Hyper Parameters
num_epochs = 3
batch_size = 2
learning_rate = 0.00015
beta = 2

# Mean and std deviation of imagenet dataset. Source: http://cs231n.stanford.edu/reports/2017/pdfs/101.pdf
std = [0.229, 0.224, 0.225]
mean = [0.485, 0.456, 0.406]

# TODO: Define train, validation and models
MODELS_PATH = 'output/models'
# TRAIN_PATH = cwd+'/train/'
# VALID_PATH = cwd+'/valid/'
VALID_PATH = cwd+'/sample/valid'
TRAIN_PATH = cwd+'/sample/train'
TEST_PATH = cwd+'/test'

if not os.path.exists(MODELS_PATH): os.mkdir(MODELS_PATH)

# %%
def customized_loss(S_prime, C_prime, S, C, B):
    ''' Calculates loss specified on the paper.'''
    
    loss_cover = torch.nn.functional.mse_loss(C_prime, C)
    loss_secret = torch.nn.functional.mse_loss(S_prime, S)
    loss_all = loss_cover + B * loss_secret
    return loss_all, loss_cover, loss_secret

def denormalize(image, std, mean):
    ''' Denormalizes a tensor of images.'''

    for t in range(3):
        image[t, :, :] = (image[t, :, :] * std[t]) + mean[t]
    return image

def imshow(img, idx, learning_rate, beta):
    '''Prints out an image given in tensor format.'''
    
    img = denormalize(img, std, mean)
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.title('Example '+str(idx)+', lr='+str(learning_rate)+', B='+str(beta))
    plt.show()
    return

def gaussian(tensor, mean=0, stddev=0.1):
    '''Adds random noise to a tensor.'''
    
    noise = torch.nn.init.normal_(torch.Tensor(tensor.size()), 0, 0.1)
    return Variable(tensor + noise)

# %%
# Preparation Network (2 conv layers)
class PrepNetwork(nn.Module):
    def __init__(self):
        super(PrepNetwork, self).__init__()
        self.initialP3 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.initialP4 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU())
        self.initialP5 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalP3 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.finalP4 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU())
        self.finalP5 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=5, padding=2),
            nn.ReLU())

    def forward(self, p):
        p1 = self.initialP3(p)
        p2 = self.initialP4(p)
        p3 = self.initialP5(p)
        mid = torch.cat((p1, p2, p3), 1)
        p4 = self.finalP3(mid)
        p5 = self.finalP4(mid)
        p6 = self.finalP5(mid)
        out = torch.cat((p4, p5, p6), 1)
        return out

# Hiding Network (5 conv layers)
class HidingNetwork(nn.Module):
    def __init__(self):
        super(HidingNetwork, self).__init__()
        self.initialH3 = nn.Sequential(
            nn.Conv2d(153, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.initialH4 = nn.Sequential(
            nn.Conv2d(153, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU())
        self.initialH5 = nn.Sequential(
            nn.Conv2d(153, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalH3 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.finalH4 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU())
        self.finalH5 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalH = nn.Sequential(
            nn.Conv2d(150, 3, kernel_size=1, padding=0))
        
    def forward(self, h):
        h1 = self.initialH3(h)
        h2 = self.initialH4(h)
        h3 = self.initialH5(h)
        mid = torch.cat((h1, h2, h3), 1)
        h4 = self.finalH3(mid)
        h5 = self.finalH4(mid)
        h6 = self.finalH5(mid)
        mid2 = torch.cat((h4, h5, h6), 1)
        out = self.finalH(mid2)
        out_noise = gaussian(out.data, 0, 0.1)
        return out, out_noise

# Reveal Network (2 conv layers)
class RevealNetwork(nn.Module):
    def __init__(self):
        super(RevealNetwork, self).__init__()
        self.initialR3 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.initialR4 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU())
        self.initialR5 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalR3 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.finalR4 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU())
        self.finalR5 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalR = nn.Sequential(
            nn.Conv2d(150, 3, kernel_size=1, padding=0))

    def forward(self, r):
        r1 = self.initialR3(r)
        r2 = self.initialR4(r)
        r3 = self.initialR5(r)
        mid = torch.cat((r1, r2, r3), 1)
        r4 = self.finalR3(mid)
        r5 = self.finalR4(mid)
        r6 = self.finalR5(mid)
        mid2 = torch.cat((r4, r5, r6), 1)
        out = self.finalR(mid2)
        return out

# Join three networks in one module
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.m1 = PrepNetwork()
        self.m2 = HidingNetwork()
        self.m3 = RevealNetwork()

    def forward(self, secret, cover):
        x_1 = self.m1(secret)
        mid = torch.cat((x_1, cover), 1)
        x_2, x_2_noise = self.m2(mid)
        x_3 = self.m3(x_2_noise)
        return x_2, x_3

# %%
# Creates net object
net = Net()

# %%
# Creates training set
train_loader = torch.utils.data.DataLoader(
        datasets.ImageFolder(
        TRAIN_PATH,
        transforms.Compose([
        transforms.Resize(256),
        transforms.RandomCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=mean,
        std=std)
        ])), batch_size=batch_size, num_workers=1, 
        pin_memory=True, shuffle=True, drop_last=True)

# Creates test set
test_loader = torch.utils.data.DataLoader(
        datasets.ImageFolder(
        TEST_PATH, 
        transforms.Compose([
        transforms.Resize(256),
        transforms.RandomCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=mean,
        std=std)
        ])), batch_size=2, num_workers=1, 
        pin_memory=True, shuffle=True, drop_last=True)

# %%
def train_model(train_loader, beta, learning_rate):
    
    # Save optimizer
    optimizer = optim.Adam(net.parameters(), lr=learning_rate, weight_decay=0.1)
    
    loss_history = []
    # Iterate over batches performing forward and backward passes
    for epoch in range(num_epochs):

        # Train mode
        net.train()
        
        train_losses = []
        # Train one epoch
        for idx, train_batch in enumerate(train_loader):

            data, _  = train_batch

            # Saves secret images and secret covers
            train_covers = data[:len(data)//2]
            train_secrets = data[len(data)//2:]
            
            # Creates variable from secret and cover images
            train_secrets = Variable(train_secrets, requires_grad=False)
            train_covers = Variable(train_covers, requires_grad=False)

            # Forward + Backward + Optimize
            optimizer.zero_grad()
            train_hidden, train_output = net(train_secrets, train_covers)

            # Calculate loss and perform backprop
            train_loss, train_loss_cover, train_loss_secret = customized_loss(train_output, train_hidden, train_secrets, train_covers, beta)
            train_loss.backward()
            optimizer.step()
            
            # Saves training loss
            train_losses.append(train_loss.item())
            loss_history.append(train_loss.item())
            
            # Prints mini-batch losses
            print('Training: Batch {0}/{1}. Loss of {2:.4f}, cover loss of {3:.4f}, secret loss of {4:.4f}'.format(idx+1, len(train_loader), train_loss.item(), train_loss_cover.item(), train_loss_secret.item()))
    
        torch.save(net.state_dict(), MODELS_PATH+'Epoch N{}.pkl'.format(epoch+1))
        
        mean_train_loss = np.mean(train_losses)
    
        # Prints epoch average loss
        print ('Epoch [{0}/{1}], Average_loss: {2:.4f}'.format(
                epoch+1, num_epochs, mean_train_loss))
    
    return net, mean_train_loss, loss_history

# %%
net, mean_train_loss, loss_history = train_model(train_loader, beta, learning_rate)
# Out:
# Training: Batch 1/90. Loss of 4.6703, cover loss of 1.1609, secret loss of 1.7547
# Training: Batch 2/90. Loss of 1.4497, cover loss of 0.9340, secret loss of 0.2578
# Training: Batch 3/90. Loss of 4.4631, cover loss of 1.7330, secret loss of 1.3650
# Training: Batch 4/90. Loss of 4.2963, cover loss of 1.6855, secret loss of 1.3054
# Training: Batch 5/90. Loss of 6.2602, cover loss of 2.1648, secret loss of 2.0477
# Training: Batch 6/90. Loss of 5.3908, cover loss of 1.5656, secret loss of 1.9126
# Training: Batch 7/90. Loss of 3.3671, cover loss of 1.1498, secret loss of 1.1086
# Training: Batch 8/90. Loss of 2.5261, cover loss of 1.4577, secret loss of 0.5342
# Training: Batch 9/90. Loss of 6.4170, cover loss of 2.9382, secret loss of 1.7394
# Training: Batch 10/90. Loss of 4.8632, cover loss of 1.4720, secret loss of 1.6956
# Training: Batch 11/90. Loss of 3.9924, cover loss of 0.9604, secret loss of 1.5160
# Training: Batch 12/90. Loss of 3.1475, cover loss of 1.6166, secret loss of 0.7655
# Training: Batch 13/90. Loss of 2.4731, cover loss of 1.0303, secret loss of 0.7214
# Training: Batch 14/90. Loss of 4.6736, cover loss of 2.1647, secret loss of 1.2545
# Training: Batch 15/90. Loss of 4.0231, cover loss of 1.4254, secret loss of 1.2989
# Training: Batch 16/90. Loss of 3.7360, cover loss of 0.8950, secret loss of 1.4205
# Training: Batch 17/90. Loss of 4.0176, cover loss of 2.0077, secret loss of 1.0049
# Training: Batch 18/90. Loss of 3.1702, cover loss of 1.5247, secret loss of 0.8228
# Training: Batch 19/90. Loss of 3.2786, cover loss of 1.4073, secret loss of 0.9356
# Training: Batch 20/90. Loss of 4.4622, cover loss of 1.1324, secret loss of 1.6649
# Training: Batch 21/90. Loss of 3.6057, cover loss of 0.8129, secret loss of 1.3964
# Training: Batch 22/90. Loss of 5.1189, cover loss of 1.9844, secret loss of 1.5673
# Training: Batch 23/90. Loss of 4.1595, cover loss of 0.9190, secret loss of 1.6203
# Training: Batch 24/90. Loss of 3.4715, cover loss of 1.4853, secret loss of 0.9931
# Training: Batch 25/90. Loss of 2.9386, cover loss of 1.7706, secret loss of 0.5840
# Training: Batch 26/90. Loss of 3.9196, cover loss of 1.2887, secret loss of 1.3155
# Training: Batch 27/90. Loss of 3.2239, cover loss of 0.9458, secret loss of 1.1391
# Training: Batch 28/90. Loss of 1.8990, cover loss of 0.8410, secret loss of 0.5290
# Training: Batch 29/90. Loss of 1.7107, cover loss of 0.8241, secret loss of 0.4433
# Training: Batch 30/90. Loss of 4.1057, cover loss of 0.9957, secret loss of 1.5550
# Training: Batch 31/90. Loss of 2.6095, cover loss of 1.0608, secret loss of 0.7743
# Training: Batch 32/90. Loss of 3.6897, cover loss of 1.1743, secret loss of 1.2577
# Training: Batch 33/90. Loss of 4.0067, cover loss of 1.4059, secret loss of 1.3004
# Training: Batch 34/90. Loss of 3.5413, cover loss of 1.1848, secret loss of 1.1783
# Training: Batch 35/90. Loss of 6.6301, cover loss of 1.3754, secret loss of 2.6274
# Training: Batch 36/90. Loss of 4.6735, cover loss of 1.1811, secret loss of 1.7462
# Training: Batch 37/90. Loss of 2.7282, cover loss of 1.1546, secret loss of 0.7868
# Training: Batch 38/90. Loss of 3.1271, cover loss of 1.0427, secret loss of 1.0422
# Training: Batch 39/90. Loss of 4.2203, cover loss of 1.5476, secret loss of 1.3363
# Training: Batch 40/90. Loss of 3.0345, cover loss of 1.6329, secret loss of 0.7008
# Training: Batch 41/90. Loss of 4.3867, cover loss of 1.3800, secret loss of 1.5033
# Training: Batch 42/90. Loss of 3.9992, cover loss of 1.0192, secret loss of 1.4900
# Training: Batch 43/90. Loss of 4.4030, cover loss of 1.3788, secret loss of 1.5121
# Training: Batch 44/90. Loss of 3.8643, cover loss of 0.8662, secret loss of 1.4990
# Training: Batch 45/90. Loss of 2.9113, cover loss of 1.3972, secret loss of 0.7571
# Training: Batch 46/90. Loss of 5.6309, cover loss of 1.7441, secret loss of 1.9434
# Training: Batch 47/90. Loss of 4.6266, cover loss of 1.6506, secret loss of 1.4880
# Training: Batch 48/90. Loss of 2.7435, cover loss of 1.3162, secret loss of 0.7136
# Training: Batch 49/90. Loss of 4.1185, cover loss of 2.5955, secret loss of 0.7615
# Training: Batch 50/90. Loss of 4.1048, cover loss of 1.2858, secret loss of 1.4095
# Training: Batch 51/90. Loss of 4.4691, cover loss of 1.7538, secret loss of 1.3577
# Training: Batch 52/90. Loss of 4.8392, cover loss of 2.0600, secret loss of 1.3896
# Training: Batch 53/90. Loss of 3.7381, cover loss of 1.0517, secret loss of 1.3432
# Training: Batch 54/90. Loss of 6.6302, cover loss of 1.8032, secret loss of 2.4135
# Training: Batch 55/90. Loss of 3.1120, cover loss of 1.1567, secret loss of 0.9777
# Training: Batch 56/90. Loss of 1.9559, cover loss of 0.7296, secret loss of 0.6132
# Training: Batch 57/90. Loss of 4.5661, cover loss of 0.9835, secret loss of 1.7913
# Training: Batch 58/90. Loss of 3.1522, cover loss of 0.8912, secret loss of 1.1305
# Training: Batch 59/90. Loss of 2.6609, cover loss of 0.3961, secret loss of 1.1324
# Training: Batch 60/90. Loss of 3.3395, cover loss of 0.6881, secret loss of 1.3257
# Training: Batch 61/90. Loss of 2.1370, cover loss of 0.3631, secret loss of 0.8869
# Training: Batch 62/90. Loss of 3.9066, cover loss of 1.2099, secret loss of 1.3483
# Training: Batch 63/90. Loss of 2.1974, cover loss of 0.6802, secret loss of 0.7586
# Training: Batch 64/90. Loss of 3.4377, cover loss of 0.6563, secret loss of 1.3907
# Training: Batch 65/90. Loss of 2.7567, cover loss of 0.5276, secret loss of 1.1146
# Training: Batch 66/90. Loss of 2.5922, cover loss of 0.7357, secret loss of 0.9282
# Training: Batch 67/90. Loss of 4.6239, cover loss of 0.7785, secret loss of 1.9227
# Training: Batch 68/90. Loss of 3.8083, cover loss of 0.1229, secret loss of 1.8427
# Training: Batch 69/90. Loss of 3.3004, cover loss of 0.6434, secret loss of 1.3285
# Training: Batch 70/90. Loss of 2.2438, cover loss of 0.7039, secret loss of 0.7700
# Training: Batch 71/90. Loss of 4.1097, cover loss of 0.3578, secret loss of 1.8760
# Training: Batch 72/90. Loss of 3.4244, cover loss of 0.4660, secret loss of 1.4792
# Training: Batch 73/90. Loss of 3.1392, cover loss of 0.2940, secret loss of 1.4226
# Training: Batch 74/90. Loss of 2.0351, cover loss of 0.3601, secret loss of 0.8375
# Training: Batch 75/90. Loss of 4.6940, cover loss of 0.2314, secret loss of 2.2313
# Training: Batch 76/90. Loss of 2.0005, cover loss of 0.2010, secret loss of 0.8997
# Training: Batch 77/90. Loss of 2.6333, cover loss of 0.5013, secret loss of 1.0660
# Training: Batch 78/90. Loss of 2.4985, cover loss of 0.3350, secret loss of 1.0818
# Training: Batch 79/90. Loss of 9.3141, cover loss of 1.0630, secret loss of 4.1256
# Training: Batch 80/90. Loss of 3.2642, cover loss of 0.2240, secret loss of 1.5201
# Training: Batch 81/90. Loss of 2.5800, cover loss of 0.2832, secret loss of 1.1484
# Training: Batch 82/90. Loss of 3.9831, cover loss of 0.4239, secret loss of 1.7796
# Training: Batch 83/90. Loss of 3.6419, cover loss of 0.5848, secret loss of 1.5285
# Training: Batch 84/90. Loss of 6.3382, cover loss of 0.3401, secret loss of 2.9990
# Training: Batch 85/90. Loss of 2.4524, cover loss of 0.7167, secret loss of 0.8679
# Training: Batch 86/90. Loss of 2.3618, cover loss of 0.8111, secret loss of 0.7753
# Training: Batch 87/90. Loss of 2.3439, cover loss of 0.1883, secret loss of 1.0778
# Training: Batch 88/90. Loss of 3.1192, cover loss of 0.3526, secret loss of 1.3833
# Training: Batch 89/90. Loss of 2.2980, cover loss of 0.5584, secret loss of 0.8698
# Training: Batch 90/90. Loss of 2.3970, cover loss of 0.1296, secret loss of 1.1337
# Epoch [1/3], Average_loss: 3.6886
# Training: Batch 1/90. Loss of 3.1003, cover loss of 0.2879, secret loss of 1.4062
# Training: Batch 2/90. Loss of 2.9627, cover loss of 0.3471, secret loss of 1.3078
# Training: Batch 3/90. Loss of 2.7021, cover loss of 0.3311, secret loss of 1.1855
# Training: Batch 4/90. Loss of 3.3789, cover loss of 0.4226, secret loss of 1.4782
# Training: Batch 5/90. Loss of 2.8086, cover loss of 0.2831, secret loss of 1.2628
# Training: Batch 6/90. Loss of 1.9426, cover loss of 0.3639, secret loss of 0.7894
# Training: Batch 7/90. Loss of 2.7028, cover loss of 0.4884, secret loss of 1.1072
# Training: Batch 8/90. Loss of 2.8205, cover loss of 0.2151, secret loss of 1.3027
# Training: Batch 9/90. Loss of 5.8197, cover loss of 0.2875, secret loss of 2.7661
# Training: Batch 10/90. Loss of 1.7582, cover loss of 0.2022, secret loss of 0.7780
# Training: Batch 11/90. Loss of 4.4501, cover loss of 0.4038, secret loss of 2.0231
# Training: Batch 12/90. Loss of 3.3667, cover loss of 0.2773, secret loss of 1.5447
# Training: Batch 13/90. Loss of 4.7631, cover loss of 0.1506, secret loss of 2.3063
# Training: Batch 14/90. Loss of 2.3646, cover loss of 0.4549, secret loss of 0.9549
# Training: Batch 15/90. Loss of 1.6536, cover loss of 0.1035, secret loss of 0.7751
# Training: Batch 16/90. Loss of 2.0282, cover loss of 0.0985, secret loss of 0.9649
# Training: Batch 17/90. Loss of 2.0683, cover loss of 0.5358, secret loss of 0.7663
# Training: Batch 18/90. Loss of 2.5145, cover loss of 0.0789, secret loss of 1.2178
# Training: Batch 19/90. Loss of 2.3581, cover loss of 0.3551, secret loss of 1.0015
# Training: Batch 20/90. Loss of 1.9927, cover loss of 0.1096, secret loss of 0.9415
# Training: Batch 21/90. Loss of 5.5543, cover loss of 0.1937, secret loss of 2.6803
# Training: Batch 22/90. Loss of 2.5557, cover loss of 0.2870, secret loss of 1.1344
# Training: Batch 23/90. Loss of 2.8238, cover loss of 0.1227, secret loss of 1.3505
# Training: Batch 24/90. Loss of 3.7660, cover loss of 0.1683, secret loss of 1.7988
# Training: Batch 25/90. Loss of 3.3625, cover loss of 0.1319, secret loss of 1.6153
# Training: Batch 26/90. Loss of 2.1632, cover loss of 0.1995, secret loss of 0.9819
# Training: Batch 27/90. Loss of 2.7087, cover loss of 0.3158, secret loss of 1.1965
# Training: Batch 28/90. Loss of 3.0255, cover loss of 0.2582, secret loss of 1.3836
# Training: Batch 29/90. Loss of 2.5890, cover loss of 0.4503, secret loss of 1.0693
# Training: Batch 30/90. Loss of 3.8757, cover loss of 0.4942, secret loss of 1.6908
# Training: Batch 31/90. Loss of 1.6540, cover loss of 0.3974, secret loss of 0.6283
# Training: Batch 32/90. Loss of 2.6348, cover loss of 0.1002, secret loss of 1.2673
# Training: Batch 33/90. Loss of 1.8452, cover loss of 0.8633, secret loss of 0.4909
# Training: Batch 34/90. Loss of 1.8013, cover loss of 0.2094, secret loss of 0.7960
# Training: Batch 35/90. Loss of 3.0933, cover loss of 0.3169, secret loss of 1.3882
# Training: Batch 36/90. Loss of 2.9106, cover loss of 0.1661, secret loss of 1.3722
# Training: Batch 37/90. Loss of 2.3597, cover loss of 0.6395, secret loss of 0.8601
# Training: Batch 38/90. Loss of 3.1336, cover loss of 0.2424, secret loss of 1.4456
# Training: Batch 39/90. Loss of 3.3572, cover loss of 0.1453, secret loss of 1.6059
# Training: Batch 40/90. Loss of 3.0644, cover loss of 0.4280, secret loss of 1.3182
# Training: Batch 41/90. Loss of 1.9213, cover loss of 0.2114, secret loss of 0.8549
# Training: Batch 42/90. Loss of 3.7711, cover loss of 0.8524, secret loss of 1.4594
# Training: Batch 43/90. Loss of 2.8535, cover loss of 0.2334, secret loss of 1.3101
# Training: Batch 44/90. Loss of 2.6673, cover loss of 0.7731, secret loss of 0.9471
# Training: Batch 45/90. Loss of 2.4127, cover loss of 0.2559, secret loss of 1.0784
# Training: Batch 46/90. Loss of 2.1300, cover loss of 0.1945, secret loss of 0.9678
# Training: Batch 47/90. Loss of 1.4863, cover loss of 0.2330, secret loss of 0.6266
# Training: Batch 48/90. Loss of 3.8135, cover loss of 0.5534, secret loss of 1.6300
# Training: Batch 49/90. Loss of 2.5388, cover loss of 0.3096, secret loss of 1.1146
# Training: Batch 50/90. Loss of 2.9993, cover loss of 0.2056, secret loss of 1.3969
# Training: Batch 51/90. Loss of 4.1341, cover loss of 0.1738, secret loss of 1.9802
# Training: Batch 52/90. Loss of 3.8042, cover loss of 0.3609, secret loss of 1.7216
# Training: Batch 53/90. Loss of 7.4677, cover loss of 0.5874, secret loss of 3.4402
# Training: Batch 54/90. Loss of 1.7775, cover loss of 0.1916, secret loss of 0.7930
# Training: Batch 55/90. Loss of 2.5546, cover loss of 0.2039, secret loss of 1.1753
# Training: Batch 56/90. Loss of 2.7910, cover loss of 0.8069, secret loss of 0.9920
# Training: Batch 57/90. Loss of 2.7888, cover loss of 0.3000, secret loss of 1.2444
# Training: Batch 58/90. Loss of 1.9191, cover loss of 0.2566, secret loss of 0.8312
# Training: Batch 59/90. Loss of 2.2486, cover loss of 0.5557, secret loss of 0.8464
# Training: Batch 60/90. Loss of 1.8378, cover loss of 0.3303, secret loss of 0.7538
# Training: Batch 61/90. Loss of 2.9881, cover loss of 0.3075, secret loss of 1.3403
# Training: Batch 62/90. Loss of 2.6639, cover loss of 0.3139, secret loss of 1.1750
# Training: Batch 63/90. Loss of 2.1828, cover loss of 0.4876, secret loss of 0.8476
# Training: Batch 64/90. Loss of 0.9273, cover loss of 0.3453, secret loss of 0.2910
# Training: Batch 65/90. Loss of 4.0591, cover loss of 0.5355, secret loss of 1.7618
# Training: Batch 66/90. Loss of 2.9306, cover loss of 0.1833, secret loss of 1.3737
# Training: Batch 67/90. Loss of 3.8606, cover loss of 0.9516, secret loss of 1.4545
# Training: Batch 68/90. Loss of 4.7503, cover loss of 0.8314, secret loss of 1.9595
# Training: Batch 69/90. Loss of 1.6454, cover loss of 0.3392, secret loss of 0.6531
# Training: Batch 70/90. Loss of 2.5771, cover loss of 0.1846, secret loss of 1.1963
# Training: Batch 71/90. Loss of 4.7032, cover loss of 0.9959, secret loss of 1.8537
# Training: Batch 72/90. Loss of 3.6300, cover loss of 0.1683, secret loss of 1.7309
# Training: Batch 73/90. Loss of 1.9848, cover loss of 0.3960, secret loss of 0.7944
# Training: Batch 74/90. Loss of 1.3088, cover loss of 0.2042, secret loss of 0.5523
# Training: Batch 75/90. Loss of 3.4807, cover loss of 0.7484, secret loss of 1.3661
# Training: Batch 76/90. Loss of 2.3867, cover loss of 0.3637, secret loss of 1.0115
# Training: Batch 77/90. Loss of 1.8868, cover loss of 0.3745, secret loss of 0.7561
# Training: Batch 78/90. Loss of 1.8285, cover loss of 0.3490, secret loss of 0.7397
# Training: Batch 79/90. Loss of 4.5420, cover loss of 0.1791, secret loss of 2.1814
# Training: Batch 80/90. Loss of 3.6577, cover loss of 0.9837, secret loss of 1.3370
# Training: Batch 81/90. Loss of 1.8514, cover loss of 0.1270, secret loss of 0.8622
# Training: Batch 82/90. Loss of 3.2621, cover loss of 0.2279, secret loss of 1.5171
# Training: Batch 83/90. Loss of 2.2421, cover loss of 0.1637, secret loss of 1.0392
# Training: Batch 84/90. Loss of 3.1966, cover loss of 0.1452, secret loss of 1.5257
# Training: Batch 85/90. Loss of 2.1060, cover loss of 0.3865, secret loss of 0.8597
# Training: Batch 86/90. Loss of 2.5390, cover loss of 0.3828, secret loss of 1.0781
# Training: Batch 87/90. Loss of 3.3486, cover loss of 0.2787, secret loss of 1.5350
# Training: Batch 88/90. Loss of 3.1841, cover loss of 0.2808, secret loss of 1.4517
# Training: Batch 89/90. Loss of 2.1861, cover loss of 0.4219, secret loss of 0.8821
# Training: Batch 90/90. Loss of 3.3995, cover loss of 0.7195, secret loss of 1.3400
# Epoch [2/3], Average_loss: 2.8785
# Training: Batch 1/90. Loss of 2.2517, cover loss of 0.3800, secret loss of 0.9358
# Training: Batch 2/90. Loss of 3.9469, cover loss of 0.3803, secret loss of 1.7833
# Training: Batch 3/90. Loss of 2.7830, cover loss of 0.4444, secret loss of 1.1693
# Training: Batch 4/90. Loss of 1.5635, cover loss of 0.6766, secret loss of 0.4435
# Training: Batch 5/90. Loss of 3.1384, cover loss of 0.2247, secret loss of 1.4568
# Training: Batch 6/90. Loss of 2.1574, cover loss of 0.2661, secret loss of 0.9457
# Training: Batch 7/90. Loss of 2.2990, cover loss of 0.5147, secret loss of 0.8921
# Training: Batch 8/90. Loss of 5.6379, cover loss of 0.2043, secret loss of 2.7168
# Training: Batch 9/90. Loss of 2.8801, cover loss of 0.3223, secret loss of 1.2789
# Training: Batch 10/90. Loss of 2.3460, cover loss of 0.2975, secret loss of 1.0242
# Training: Batch 11/90. Loss of 2.3671, cover loss of 0.1862, secret loss of 1.0904
# Training: Batch 12/90. Loss of 3.7155, cover loss of 0.7276, secret loss of 1.4940
# Training: Batch 13/90. Loss of 2.5920, cover loss of 0.3782, secret loss of 1.1069
# Training: Batch 14/90. Loss of 2.6657, cover loss of 0.4356, secret loss of 1.1151
# Training: Batch 15/90. Loss of 3.3888, cover loss of 0.4788, secret loss of 1.4550
# Training: Batch 16/90. Loss of 3.0019, cover loss of 0.6529, secret loss of 1.1745
# Training: Batch 17/90. Loss of 3.5924, cover loss of 0.8396, secret loss of 1.3764
# Training: Batch 18/90. Loss of 3.3480, cover loss of 0.4959, secret loss of 1.4261
# Training: Batch 19/90. Loss of 6.8860, cover loss of 0.1965, secret loss of 3.3447
# Training: Batch 20/90. Loss of 1.5323, cover loss of 0.3102, secret loss of 0.6110
# Training: Batch 21/90. Loss of 4.4063, cover loss of 0.0895, secret loss of 2.1584
# Training: Batch 22/90. Loss of 3.4882, cover loss of 0.4324, secret loss of 1.5279
# Training: Batch 23/90. Loss of 3.0148, cover loss of 0.6182, secret loss of 1.1983
# Training: Batch 24/90. Loss of 2.3187, cover loss of 0.4135, secret loss of 0.9526
# Training: Batch 25/90. Loss of 4.2353, cover loss of 0.4438, secret loss of 1.8957
# Training: Batch 26/90. Loss of 3.3948, cover loss of 0.6796, secret loss of 1.3576
# Training: Batch 27/90. Loss of 3.2251, cover loss of 0.2116, secret loss of 1.5067
# Training: Batch 28/90. Loss of 1.6090, cover loss of 0.3159, secret loss of 0.6466
# Training: Batch 29/90. Loss of 2.5998, cover loss of 0.2426, secret loss of 1.1786
# Training: Batch 30/90. Loss of 3.1973, cover loss of 0.1369, secret loss of 1.5302
# Training: Batch 31/90. Loss of 2.6547, cover loss of 0.4019, secret loss of 1.1264
# Training: Batch 32/90. Loss of 3.1378, cover loss of 0.1301, secret loss of 1.5039
# Training: Batch 33/90. Loss of 2.0752, cover loss of 0.1212, secret loss of 0.9770
# Training: Batch 34/90. Loss of 2.9141, cover loss of 0.1870, secret loss of 1.3636
# Training: Batch 35/90. Loss of 2.2560, cover loss of 0.2747, secret loss of 0.9906
# Training: Batch 36/90. Loss of 1.8420, cover loss of 0.1820, secret loss of 0.8300
# Training: Batch 37/90. Loss of 5.3164, cover loss of 0.9853, secret loss of 2.1656
# Training: Batch 38/90. Loss of 2.0445, cover loss of 0.2237, secret loss of 0.9104
# Training: Batch 39/90. Loss of 3.4389, cover loss of 0.2646, secret loss of 1.5871
# Training: Batch 40/90. Loss of 4.0174, cover loss of 0.4255, secret loss of 1.7959
# Training: Batch 41/90. Loss of 1.5686, cover loss of 0.3875, secret loss of 0.5905
# Training: Batch 42/90. Loss of 2.9934, cover loss of 0.3531, secret loss of 1.3202
# Training: Batch 43/90. Loss of 3.3905, cover loss of 0.9300, secret loss of 1.2303
# Training: Batch 44/90. Loss of 2.7245, cover loss of 0.0875, secret loss of 1.3185
# Training: Batch 45/90. Loss of 2.1357, cover loss of 0.1977, secret loss of 0.9690
# Training: Batch 46/90. Loss of 4.2555, cover loss of 0.4752, secret loss of 1.8901
# Training: Batch 47/90. Loss of 4.0648, cover loss of 0.1722, secret loss of 1.9463
# Training: Batch 48/90. Loss of 1.3370, cover loss of 0.0892, secret loss of 0.6239
# Training: Batch 49/90. Loss of 2.2502, cover loss of 0.3872, secret loss of 0.9315
# Training: Batch 50/90. Loss of 5.7045, cover loss of 0.2488, secret loss of 2.7278
# Training: Batch 51/90. Loss of 5.5484, cover loss of 0.9221, secret loss of 2.3132
# Training: Batch 52/90. Loss of 4.0912, cover loss of 0.7753, secret loss of 1.6580
# Training: Batch 53/90. Loss of 4.1390, cover loss of 0.5261, secret loss of 1.8064
# Training: Batch 54/90. Loss of 2.4518, cover loss of 0.1734, secret loss of 1.1392
# Training: Batch 55/90. Loss of 2.6197, cover loss of 0.0713, secret loss of 1.2742
# Training: Batch 56/90. Loss of 3.9409, cover loss of 0.2162, secret loss of 1.8624
# Training: Batch 57/90. Loss of 3.2402, cover loss of 0.3190, secret loss of 1.4606
# Training: Batch 58/90. Loss of 2.9268, cover loss of 0.3392, secret loss of 1.2938
# Training: Batch 59/90. Loss of 3.1895, cover loss of 0.3235, secret loss of 1.4330
# Training: Batch 60/90. Loss of 2.4461, cover loss of 0.1980, secret loss of 1.1240
# Training: Batch 61/90. Loss of 2.0400, cover loss of 0.4093, secret loss of 0.8153
# Training: Batch 62/90. Loss of 2.4075, cover loss of 0.2574, secret loss of 1.0750
# Training: Batch 63/90. Loss of 2.2498, cover loss of 0.2089, secret loss of 1.0205
# Training: Batch 64/90. Loss of 3.5773, cover loss of 0.8904, secret loss of 1.3435
# Training: Batch 65/90. Loss of 2.9613, cover loss of 0.3101, secret loss of 1.3256
# Training: Batch 66/90. Loss of 2.8157, cover loss of 0.1645, secret loss of 1.3256
# Training: Batch 67/90. Loss of 2.3410, cover loss of 0.1597, secret loss of 1.0907
# Training: Batch 68/90. Loss of 3.2733, cover loss of 0.4450, secret loss of 1.4142
# Training: Batch 69/90. Loss of 3.3933, cover loss of 0.1725, secret loss of 1.6104
# Training: Batch 70/90. Loss of 1.7283, cover loss of 0.2133, secret loss of 0.7575
# Training: Batch 71/90. Loss of 1.6709, cover loss of 0.1676, secret loss of 0.7517
# Training: Batch 72/90. Loss of 1.2998, cover loss of 0.3917, secret loss of 0.4540
# Training: Batch 73/90. Loss of 2.5020, cover loss of 0.1645, secret loss of 1.1688
# Training: Batch 74/90. Loss of 4.2017, cover loss of 0.2345, secret loss of 1.9836
# Training: Batch 75/90. Loss of 3.2806, cover loss of 0.3993, secret loss of 1.4406
# Training: Batch 76/90. Loss of 1.8543, cover loss of 0.4522, secret loss of 0.7010
# Training: Batch 77/90. Loss of 3.3177, cover loss of 0.3441, secret loss of 1.4868
# Training: Batch 78/90. Loss of 1.3716, cover loss of 0.4115, secret loss of 0.4800
# Training: Batch 79/90. Loss of 1.8670, cover loss of 0.2456, secret loss of 0.8107
# Training: Batch 80/90. Loss of 3.1464, cover loss of 0.3320, secret loss of 1.4072
# Training: Batch 81/90. Loss of 2.6500, cover loss of 0.2479, secret loss of 1.2011
# Training: Batch 82/90. Loss of 4.2153, cover loss of 0.1983, secret loss of 2.0085
# Training: Batch 83/90. Loss of 2.1533, cover loss of 0.3096, secret loss of 0.9218
# Training: Batch 84/90. Loss of 4.8293, cover loss of 0.3036, secret loss of 2.2629
# Training: Batch 85/90. Loss of 4.9473, cover loss of 0.7209, secret loss of 2.1132
# Training: Batch 86/90. Loss of 1.8784, cover loss of 0.3290, secret loss of 0.7747
# Training: Batch 87/90. Loss of 3.8182, cover loss of 0.0789, secret loss of 1.8696
# Training: Batch 88/90. Loss of 3.0408, cover loss of 0.1065, secret loss of 1.4671
# Training: Batch 89/90. Loss of 3.5317, cover loss of 0.8335, secret loss of 1.3491
# Training: Batch 90/90. Loss of 3.0389, cover loss of 0.2544, secret loss of 1.3923
# Epoch [3/3], Average_loss: 3.0411

# %%
# Plot loss through epochs
plt.plot(loss_history)
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Batch')
plt.show()

# %%
# Switch to evaluate mode
net.eval()

test_losses = []
# Show images
for idx, test_batch in enumerate(test_loader):
     # Saves images
    data, _ = test_batch

    # Saves secret images and secret covers
    test_secret = data[:len(data)//2]
    test_cover = data[len(data)//2:]

    # Creates variable from secret and cover images
    with torch.no_grad():
        test_secret = Variable(test_secret)
        test_cover = Variable(test_cover)

    # Compute output
    test_hidden, test_output = net(test_secret, test_cover)
    
    # Calculate loss
    test_loss, loss_cover, loss_secret = customized_loss(test_output, test_hidden, test_secret, test_cover, beta)
    
    
    if idx in [0,1,2,3]:
        print ('Total loss: {:.2f} \nLoss on secret: {:.2f} \nLoss on cover: {:.2f}'.format(test_loss.item(), loss_secret.item(), loss_cover.item()))

        # Creates img tensor
        imgs = [test_secret.data, test_output.data, test_cover.data, test_hidden.data]
        
        imgs_tsor = torch.cat(imgs, 0)

        # Prints Images
        imshow(utils.make_grid(imgs_tsor), idx+1, learning_rate=learning_rate, beta=beta)
        
    test_losses.append(test_loss.item())
        
mean_test_loss = np.mean(test_losses)

print ('Average loss on test set: {:.2f}'.format(mean_test_loss))
# Out:
# Total loss: 2.17
# Loss on secret: 0.88
# Loss on cover: 0.41
# Total loss: 2.05
# Loss on secret: 0.93
# Loss on cover: 0.18
# Total loss: 2.30
# Loss on secret: 0.76
# Loss on cover: 0.79
# Total loss: 2.34
# Loss on secret: 1.08
# Loss on cover: 0.17
# Average loss on test set: 1.95
